# %% [markdown]
# # Weather Features Data Exploration
#
# This notebook explores the `weather_features.parquet` dataset to understand its structure, contents, and basic statistics. We'll analyze sample data, check for missing values, and visualize key distributions.

# %%
import pyarrow.parquet as pq
import pandas as pd
from pathlib import Path


def show_full_sample(file_path, sample_rows=5, random_sample=False):
    """
    Display sample data with ALL columns without full file load.
    
    Args:
        file_path (str): Path to Parquet file
        sample_rows (int): Number of rows to display
        random_sample (bool): If True, takes random rows (slower)
        
    Returns:
        pandas.DataFrame: The sample data
    """
    # Open file and read metadata only
    parquet_file = pq.ParquetFile(file_path)
    total_rows = parquet_file.metadata.num_rows
    columns = parquet_file.schema.names
    
    print(f"=== Parquet File ===")
    print(f"Path: {file_path}")
    print(f"Total rows: {total_rows:,}")
    print(f"Columns ({len(columns)}): {columns}")
    
    if random_sample:
        # Random sampling (more representative but slightly slower)
        import random
        row_indices = random.sample(range(total_rows), min(sample_rows, total_rows))
        sample = pq.read_table(
            file_path,
            filters=[('index', 'in', row_indices)]
        ).to_pandas()
    else:
        # Fast sequential sampling (first N rows)
        sample = parquet_file.read_row_group(0).to_pandas().head(sample_rows)
    
    print(f"\nSample data ({'random' if random_sample else 'first'} {len(sample)} rows):")
    pd.set_option('display.max_columns', None)  # Show all columns

    
    return sample  # Return the sample dataframe

# %%
root = project_root = Path().resolve().parents[0]
path_file = root / "data/interim/weather_features.parquet"
print(path_file)
data = show_full_sample(
        file_path=path_file,
        sample_rows=5,
        random_sample=False  # Set True for random sampling
)

display(data)
# Out:
# D:\FCAI\data_science\project\wildfire_prediction\wildfire_prediction\data\interim\weather_features.parquet
# === Parquet File ===
# Path: D:\FCAI\data_science\project\wildfire_prediction\wildfire_prediction\data\interim\weather_features.parquet
# Total rows: 103,304,160
# Columns (34): ['longitude', 'latitude', 'ppt', 'tmax', 'vbdmax', 'date', 'year', 'month', 'day_of_year', 'grid_id', 'week', 'hot_dry_index', 'high_temp_day', 'low_rain_day', 'hot_dry_day', 'spi_7day', 'drought_category', 'vpd_extreme', 'vpd_anomaly', 'vpd_risk_category', 'is_fire_season', 'is_santa_ana_season', 'season', 'week_sin', 'week_cos', 'month_sin', 'month_cos', 'tmax_7day_mean', 'ppt_7day_mean', 'vbd_7day_mean', 'fire_weather_index', 'drought_weather_index', 'fire_risk_index', 'date_bin']
#
# Sample data (first 5 rows):
#     longitude   latitude    ppt   tmax  vbdmax       date  year  month  \
# 0 -124.166667  41.958333  4.730  9.725   1.458 2013-01-08  2013      1
# 1 -123.291667  41.958333  0.000  4.278   1.337 2013-01-08  2013      1
# 2 -123.333333  41.958333  0.000  5.405   1.973 2013-01-08  2013      1
# 3 -118.291667  36.958333  0.000  9.133   8.773 2013-01-08  2013      1
# 4 -124.083333  41.958333  5.099  9.407   1.187 2013-01-08  2013      1
#
#    day_of_year       grid_id                   week  hot_dry_index  \
# 0            8  10T_403_4645  2013-01-07/2013-01-13       1.564292
# 1            8  10T_475_4645  2013-01-07/2013-01-13       1.528848
# 2            8  10T_472_4645  2013-01-07/2013-01-13       1.552425
# 3            8  11S_385_4091  2013-01-07/2013-01-13       1.630413
# 4            8  10T_410_4645  2013-01-07/2013-01-13       1.551516
#
#    high_temp_day  low_rain_day  hot_dry_day  spi_7day  drought_category  \
# 0              0             0            0  0.000000                 1
# 1              0             1            0  1.130235                 0
# 2              0             1            0  1.434517                 0
# 3              0             1            0  1.684421                 0
# 4              0             0            0  1.744296                 0
#
#    vpd_extreme  vpd_anomaly  vpd_risk_category  is_fire_season  \
# 0            0    -1.261411                  1               0
# 1            0    -1.287608                  1               0
# 2            0    -1.149912                  1               0
# 3            0     0.322312                  4               0
# 4            0    -1.320083                  1               0
#
#    is_santa_ana_season  season  week_sin  week_cos  month_sin  month_cos  \
# 0                    1       0  0.120537  0.992709        0.5   0.866025
# 1                    1       0  0.120537  0.992709        0.5   0.866025
# 2                    1       0  0.120537  0.992709        0.5   0.866025
# 3                    1       0  0.120537  0.992709        0.5   0.866025
# 4                    1       0  0.120537  0.992709        0.5   0.866025
#
#    tmax_7day_mean  ppt_7day_mean  vbd_7day_mean  fire_weather_index  \
# 0             NaN            NaN            NaN            2.277418
# 1             NaN            NaN            NaN            2.218637
# 2        6.469333       1.576667       1.589333            2.257737
# 3        7.135250       1.182500       3.385250            3.887073
# 4        7.589600       1.965800       2.945600            2.256229
#
#    drought_weather_index  fire_risk_index               date_bin
# 0               1.766451         1.843096  2013-01-08_2013-01-14
# 1               1.031182         1.464301  2013-01-08_2013-01-14
# 2               1.054642         1.490106  2013-01-08_2013-01-14
# 3               1.132244         2.565468  2013-01-08_2013-01-14
# 4               1.053738         1.489111  2013-01-08_2013-01-14

# %% [markdown]
# ## Metadata and Statistics Analysis
#
# Below we extract more detailed information from the parquet file metadata and calculate key statistics for our weather features dataset. This helps us understand the data structure, storage efficiency, and distribution of values.

# %%
def analyze_parquet_metadata(file_path):
    """Analyze and display detailed metadata statistics from a parquet file"""
    # Open the parquet file
    parquet_file = pq.ParquetFile(file_path)
    metadata = parquet_file.metadata
    schema = parquet_file.schema
    
    # Basic file information
    print(f"=== Parquet File Metadata Analysis ===")
    print(f"File size: {Path(file_path).stat().st_size / (1024*1024):.2f} MB")
    print(f"Number of row groups: {metadata.num_row_groups}")
    print(f"Total rows: {metadata.num_rows:,}")
    print(f"Created by: {metadata.created_by if metadata.created_by else 'Unknown'}")
    
    # Row group details
    print(f"\n=== Row Group Information ===")
    for i in range(metadata.num_row_groups):
        row_group = metadata.row_group(i)
        print(f"Row Group #{i}: {row_group.num_rows:,} rows, "
              f"{row_group.total_byte_size / (1024*1024):.2f} MB compressed")
    
    # Column details
    print(f"\n=== Column Details ===")
    all_cols = []
    for i in range(metadata.num_row_groups):
        row_group = metadata.row_group(i)
        for j in range(row_group.num_columns):
            col = row_group.column(j)
            all_cols.append({
                'name': col.path_in_schema,
                'type': schema.field_by_name(col.path_in_schema).type,
                'compression': col.compression,
                'size_mb': col.total_compressed_size / (1024*1024),
                'encodings': col.encodings
            })
    
    # Convert to dataframe for easy display
    cols_df = pd.DataFrame(all_cols)
    cols_df = cols_df.drop_duplicates(subset='name')
    
    # Display as styled table
    from IPython.display import display, HTML
    style = """
    <style>
        .stats-table {width: 100%; border-collapse: collapse;}
        .stats-table th {background-color: #e6f2ff; color: black; text-align: left; padding: 8px; border: 1px solid #ddd;}
        .stats-table td {padding: 8px; border: 1px solid #ddd;}
        .stats-table tr:nth-child(even) {background-color: #f9f9f9;}
        .stats-table tr:hover {background-color: #f2f2f2;}
    </style>
    """
    display(HTML(style + cols_df.to_html(classes='stats-table')))
    
    return cols_df

# Call the function with our parquet file
metadata_stats = analyze_parquet_metadata(path_file)
# Out:
# === Parquet File Metadata Analysis ===
# File size: 6345.03 MB
# Number of row groups: 618
# Total rows: 103,304,160
# Created by: parquet-cpp-arrow version 20.0.0
#
# === Row Group Information ===
# Row Group #0: 167,391 rows, 10.05 MB compressed
# Row Group #1: 167,391 rows, 7.30 MB compressed
# Row Group #2: 167,391 rows, 7.46 MB compressed
# Row Group #3: 167,391 rows, 7.59 MB compressed
# Row Group #4: 167,391 rows, 9.07 MB compressed
# Row Group #5: 167,391 rows, 10.29 MB compressed
# Row Group #6: 167,391 rows, 12.44 MB compressed
# Row Group #7: 167,391 rows, 10.26 MB compressed
# Row Group #8: 167,391 rows, 8.80 MB compressed
# Row Group #9: 167,391 rows, 7.77 MB compressed
# Row Group #10: 167,391 rows, 9.16 MB compressed
# Row Group #11: 167,391 rows, 11.48 MB compressed
# Row Group #12: 167,391 rows, 10.71 MB compressed
# Row Group #13: 167,391 rows, 11.24 MB compressed
# Row Group #14: 167,391 rows, 8.92 MB compressed
# Row Group #15: 167,391 rows, 8.99 MB compressed
# Row Group #16: 167,391 rows, 7.96 MB compressed
# Row Group #17: 167,391 rows, 8.67 MB compressed
# Row Group #18: 167,391 rows, 11.17 MB compressed
# Row Group #19: 167,391 rows, 9.16 MB compressed
# Row Group #20: 167,391 rows, 8.78 MB compressed
# Row Group #21: 167,391 rows, 9.44 MB compressed
# Row Group #22: 167,391 rows, 8.54 MB compressed
# Row Group #23: 167,391 rows, 8.66 MB compressed
# Row Group #24: 167,391 rows, 9.09 MB compressed
# Row Group #25: 167,391 rows, 10.13 MB compressed
# Row Group #26: 167,391 rows, 8.92 MB compressed
# Row Group #27: 167,391 rows, 8.55 MB compressed
# Row Group #28: 167,391 rows, 8.93 MB compressed
# Row Group #29: 167,391 rows, 8.13 MB compressed
# Row Group #30: 167,391 rows, 9.75 MB compressed
# Row Group #31: 167,391 rows, 8.54 MB compressed
# Row Group #32: 167,391 rows, 10.04 MB compressed
# Row Group #33: 167,391 rows, 8.46 MB compressed
# Row Group #34: 167,391 rows, 9.12 MB compressed
# Row Group #35: 167,391 rows, 8.54 MB compressed
# Row Group #36: 167,391 rows, 9.31 MB compressed
# Row Group #37: 167,391 rows, 8.23 MB compressed
# Row Group #38: 167,391 rows, 9.99 MB compressed
# Row Group #39: 167,391 rows, 9.47 MB compressed
# Row Group #40: 167,391 rows, 8.99 MB compressed
# Row Group #41: 167,391 rows, 7.32 MB compressed
# Row Group #42: 167,391 rows, 8.06 MB compressed
# Row Group #43: 167,391 rows, 9.12 MB compressed
# Row Group #44: 167,391 rows, 7.56 MB compressed
# Row Group #45: 167,391 rows, 8.24 MB compressed
# Row Group #46: 167,391 rows, 7.16 MB compressed
# Row Group #47: 167,391 rows, 11.64 MB compressed
# Row Group #48: 167,391 rows, 10.43 MB compressed
# Row Group #49: 167,391 rows, 7.49 MB compressed
# Row Group #50: 167,391 rows, 7.16 MB compressed
# Row Group #51: 167,391 rows, 8.36 MB compressed
# Row Group #52: 167,391 rows, 6.80 MB compressed
# Row Group #53: 167,391 rows, 7.24 MB compressed
# Row Group #54: 167,391 rows, 8.71 MB compressed
# Row Group #55: 167,391 rows, 7.15 MB compressed
# Row Group #56: 167,391 rows, 10.80 MB compressed
# Row Group #57: 167,391 rows, 12.01 MB compressed
# Row Group #58: 167,391 rows, 8.24 MB compressed
# Row Group #59: 167,391 rows, 10.29 MB compressed
# Row Group #60: 167,391 rows, 11.11 MB compressed
# Row Group #61: 167,391 rows, 8.33 MB compressed
# Row Group #62: 167,391 rows, 13.44 MB compressed
# Row Group #63: 167,391 rows, 7.55 MB compressed
# Row Group #64: 167,391 rows, 12.72 MB compressed
# Row Group #65: 167,391 rows, 11.64 MB compressed
# Row Group #66: 167,391 rows, 7.85 MB compressed
# Row Group #67: 167,391 rows, 8.04 MB compressed
# Row Group #68: 167,391 rows, 8.35 MB compressed
# Row Group #69: 167,391 rows, 8.31 MB compressed
# Row Group #70: 167,391 rows, 11.84 MB compressed
# Row Group #71: 167,391 rows, 10.10 MB compressed
# Row Group #72: 167,391 rows, 9.92 MB compressed
# Row Group #73: 167,391 rows, 8.15 MB compressed
# Row Group #74: 167,391 rows, 8.15 MB compressed
# Row Group #75: 167,391 rows, 8.30 MB compressed
# Row Group #76: 167,391 rows, 8.87 MB compressed
# Row Group #77: 167,391 rows, 8.15 MB compressed
# Row Group #78: 167,391 rows, 8.61 MB compressed
# Row Group #79: 167,391 rows, 8.85 MB compressed
# Row Group #80: 167,391 rows, 9.12 MB compressed
# Row Group #81: 167,391 rows, 9.02 MB compressed
# Row Group #82: 167,391 rows, 10.01 MB compressed
# Row Group #83: 167,391 rows, 9.41 MB compressed
# Row Group #84: 167,391 rows, 8.04 MB compressed
# Row Group #85: 167,391 rows, 9.02 MB compressed
# Row Group #86: 167,391 rows, 8.40 MB compressed
# Row Group #87: 167,391 rows, 8.34 MB compressed
# Row Group #88: 167,391 rows, 8.35 MB compressed
# Row Group #89: 167,391 rows, 9.12 MB compressed
# Row Group #90: 167,391 rows, 10.96 MB compressed
# Row Group #91: 167,391 rows, 7.91 MB compressed
# Row Group #92: 167,391 rows, 7.68 MB compressed
# Row Group #93: 167,391 rows, 9.27 MB compressed
# Row Group #94: 167,391 rows, 10.65 MB compressed
# Row Group #95: 167,391 rows, 10.51 MB compressed
# Row Group #96: 167,391 rows, 7.79 MB compressed
# Row Group #97: 167,391 rows, 9.64 MB compressed
# Row Group #98: 167,391 rows, 10.85 MB compressed
# Row Group #99: 167,391 rows, 9.97 MB compressed
# Row Group #100: 167,391 rows, 9.17 MB compressed
# Row Group #101: 167,391 rows, 12.98 MB compressed
# Row Group #102: 167,391 rows, 12.96 MB compressed
# Row Group #103: 167,391 rows, 12.15 MB compressed
# Row Group #104: 167,391 rows, 8.03 MB compressed
# Row Group #105: 167,391 rows, 8.54 MB compressed
# Row Group #106: 167,391 rows, 9.03 MB compressed
# Row Group #107: 167,391 rows, 7.65 MB compressed
# Row Group #108: 167,391 rows, 9.52 MB compressed
# Row Group #109: 167,391 rows, 11.28 MB compressed
# Row Group #110: 167,391 rows, 8.12 MB compressed
# Row Group #111: 167,391 rows, 8.61 MB compressed
# Row Group #112: 167,391 rows, 10.42 MB compressed
# Row Group #113: 167,391 rows, 8.56 MB compressed
# Row Group #114: 167,391 rows, 9.28 MB compressed
# Row Group #115: 167,391 rows, 9.16 MB compressed
# Row Group #116: 167,391 rows, 8.79 MB compressed
# Row Group #117: 167,391 rows, 9.35 MB compressed
# Row Group #118: 167,391 rows, 9.90 MB compressed
# Row Group #119: 167,391 rows, 8.34 MB compressed
# Row Group #120: 167,391 rows, 10.94 MB compressed
# Row Group #121: 167,391 rows, 7.82 MB compressed
# Row Group #122: 167,391 rows, 9.56 MB compressed
# Row Group #123: 167,391 rows, 11.40 MB compressed
# Row Group #124: 167,391 rows, 8.54 MB compressed
# Row Group #125: 167,391 rows, 11.31 MB compressed
# Row Group #126: 167,391 rows, 9.73 MB compressed
# Row Group #127: 167,391 rows, 10.04 MB compressed
# Row Group #128: 167,391 rows, 8.30 MB compressed
# Row Group #129: 167,391 rows, 8.24 MB compressed
# Row Group #130: 167,391 rows, 10.06 MB compressed
# Row Group #131: 167,391 rows, 10.34 MB compressed
# Row Group #132: 167,391 rows, 9.00 MB compressed
# Row Group #133: 167,391 rows, 9.60 MB compressed
# Row Group #134: 167,391 rows, 9.13 MB compressed
# Row Group #135: 167,391 rows, 8.83 MB compressed
# Row Group #136: 167,391 rows, 8.30 MB compressed
# Row Group #137: 167,391 rows, 8.01 MB compressed
# Row Group #138: 167,391 rows, 8.73 MB compressed
# Row Group #139: 167,391 rows, 8.06 MB compressed
# Row Group #140: 167,391 rows, 8.32 MB compressed
# Row Group #141: 167,391 rows, 10.30 MB compressed
# Row Group #142: 167,391 rows, 7.83 MB compressed
# Row Group #143: 167,391 rows, 10.06 MB compressed
# Row Group #144: 167,391 rows, 8.47 MB compressed
# Row Group #145: 167,391 rows, 11.63 MB compressed
# Row Group #146: 167,391 rows, 8.28 MB compressed
# Row Group #147: 167,391 rows, 10.01 MB compressed
# Row Group #148: 167,391 rows, 10.69 MB compressed
# Row Group #149: 167,391 rows, 8.38 MB compressed
# Row Group #150: 167,391 rows, 10.70 MB compressed
# Row Group #151: 167,391 rows, 10.22 MB compressed
# Row Group #152: 167,391 rows, 10.32 MB compressed
# Row Group #153: 167,391 rows, 12.74 MB compressed
# Row Group #154: 167,391 rows, 11.03 MB compressed
# Row Group #155: 167,391 rows, 12.33 MB compressed
# Row Group #156: 167,391 rows, 9.28 MB compressed
# Row Group #157: 167,391 rows, 12.08 MB compressed
# Row Group #158: 167,391 rows, 13.48 MB compressed
# Row Group #159: 167,391 rows, 12.31 MB compressed
# Row Group #160: 167,391 rows, 11.32 MB compressed
# Row Group #161: 167,391 rows, 9.16 MB compressed
# Row Group #162: 167,391 rows, 7.74 MB compressed
# Row Group #163: 167,391 rows, 11.03 MB compressed
# Row Group #164: 167,391 rows, 8.16 MB compressed
# Row Group #165: 167,391 rows, 12.35 MB compressed
# Row Group #166: 167,391 rows, 9.46 MB compressed
# Row Group #167: 167,391 rows, 13.48 MB compressed
# Row Group #168: 167,391 rows, 9.78 MB compressed
# Row Group #169: 167,391 rows, 8.90 MB compressed
# Row Group #170: 167,391 rows, 11.56 MB compressed
# Row Group #171: 167,391 rows, 9.91 MB compressed
# Row Group #172: 167,391 rows, 10.24 MB compressed
# Row Group #173: 167,391 rows, 8.57 MB compressed
# Row Group #174: 167,391 rows, 10.63 MB compressed
# Row Group #175: 167,391 rows, 11.95 MB compressed
# Row Group #176: 167,391 rows, 10.02 MB compressed
# Row Group #177: 167,391 rows, 9.81 MB compressed
# Row Group #178: 167,391 rows, 8.46 MB compressed
# Row Group #179: 167,391 rows, 8.96 MB compressed
# Row Group #180: 167,391 rows, 9.82 MB compressed
# Row Group #181: 167,391 rows, 8.31 MB compressed
# Row Group #182: 167,391 rows, 8.67 MB compressed
# Row Group #183: 167,391 rows, 8.70 MB compressed
# Row Group #184: 167,391 rows, 8.16 MB compressed
# Row Group #185: 167,391 rows, 8.33 MB compressed
# Row Group #186: 167,391 rows, 8.22 MB compressed
# Row Group #187: 167,391 rows, 8.48 MB compressed
# Row Group #188: 167,391 rows, 8.07 MB compressed
# Row Group #189: 167,391 rows, 8.31 MB compressed
# Row Group #190: 167,391 rows, 8.31 MB compressed
# Row Group #191: 167,391 rows, 8.22 MB compressed
# Row Group #192: 167,391 rows, 7.84 MB compressed
# Row Group #193: 167,391 rows, 8.17 MB compressed
# Row Group #194: 167,391 rows, 9.06 MB compressed
# Row Group #195: 167,391 rows, 8.63 MB compressed
# Row Group #196: 167,391 rows, 8.82 MB compressed
# Row Group #197: 167,391 rows, 11.02 MB compressed
# Row Group #198: 167,391 rows, 9.63 MB compressed
# Row Group #199: 167,391 rows, 9.33 MB compressed
# Row Group #200: 167,391 rows, 13.22 MB compressed
# Row Group #201: 167,391 rows, 8.05 MB compressed
# Row Group #202: 167,391 rows, 11.39 MB compressed
# Row Group #203: 167,391 rows, 8.91 MB compressed
# Row Group #204: 167,391 rows, 12.45 MB compressed
# Row Group #205: 167,391 rows, 11.45 MB compressed
# Row Group #206: 167,391 rows, 11.34 MB compressed
# Row Group #207: 167,391 rows, 11.20 MB compressed
# Row Group #208: 167,391 rows, 10.11 MB compressed
# Row Group #209: 167,391 rows, 13.96 MB compressed
# Row Group #210: 167,391 rows, 12.82 MB compressed
# Row Group #211: 167,391 rows, 9.06 MB compressed
# Row Group #212: 167,391 rows, 14.01 MB compressed
# Row Group #213: 167,391 rows, 11.76 MB compressed
# Row Group #214: 167,391 rows, 12.00 MB compressed
# Row Group #215: 167,391 rows, 12.76 MB compressed
# Row Group #216: 167,391 rows, 13.37 MB compressed
# Row Group #217: 167,391 rows, 9.17 MB compressed
# Row Group #218: 167,391 rows, 10.70 MB compressed
# Row Group #219: 167,391 rows, 9.24 MB compressed
# Row Group #220: 167,391 rows, 13.65 MB compressed
# Row Group #221: 167,391 rows, 9.39 MB compressed
# Row Group #222: 167,391 rows, 11.34 MB compressed
# Row Group #223: 167,391 rows, 11.17 MB compressed
# Row Group #224: 167,391 rows, 9.24 MB compressed
# Row Group #225: 167,391 rows, 9.92 MB compressed
# Row Group #226: 167,391 rows, 11.51 MB compressed
# Row Group #227: 167,391 rows, 9.37 MB compressed
# Row Group #228: 167,391 rows, 9.26 MB compressed
# Row Group #229: 167,391 rows, 8.42 MB compressed
# Row Group #230: 167,391 rows, 9.29 MB compressed
# Row Group #231: 167,391 rows, 10.72 MB compressed
# Row Group #232: 167,391 rows, 8.91 MB compressed
# Row Group #233: 167,391 rows, 8.30 MB compressed
# Row Group #234: 167,391 rows, 8.76 MB compressed
# Row Group #235: 167,391 rows, 8.44 MB compressed
# Row Group #236: 167,391 rows, 8.07 MB compressed
# Row Group #237: 167,391 rows, 8.11 MB compressed
# Row Group #238: 167,391 rows, 8.78 MB compressed
# Row Group #239: 167,391 rows, 10.00 MB compressed
# Row Group #240: 167,391 rows, 8.77 MB compressed
# Row Group #241: 167,391 rows, 8.31 MB compressed
# Row Group #242: 167,391 rows, 8.58 MB compressed
# Row Group #243: 167,391 rows, 9.24 MB compressed
# Row Group #244: 167,391 rows, 10.19 MB compressed
# Row Group #245: 167,391 rows, 9.51 MB compressed
# Row Group #246: 167,391 rows, 9.60 MB compressed
# Row Group #247: 167,391 rows, 7.84 MB compressed
# Row Group #248: 167,391 rows, 7.94 MB compressed
# Row Group #249: 167,391 rows, 7.74 MB compressed
# Row Group #250: 167,391 rows, 9.83 MB compressed
# Row Group #251: 167,391 rows, 7.70 MB compressed
# Row Group #252: 167,391 rows, 9.93 MB compressed
# Row Group #253: 167,391 rows, 10.01 MB compressed
# Row Group #254: 167,391 rows, 11.29 MB compressed
# Row Group #255: 167,391 rows, 10.40 MB compressed
# Row Group #256: 167,391 rows, 9.24 MB compressed
# Row Group #257: 167,391 rows, 7.42 MB compressed
# Row Group #258: 167,391 rows, 7.78 MB compressed
# Row Group #259: 167,391 rows, 8.72 MB compressed
# Row Group #260: 167,391 rows, 7.59 MB compressed
# Row Group #261: 167,391 rows, 11.00 MB compressed
# Row Group #262: 167,391 rows, 11.09 MB compressed
# Row Group #263: 167,391 rows, 11.15 MB compressed
# Row Group #264: 167,391 rows, 10.81 MB compressed
# Row Group #265: 167,391 rows, 7.69 MB compressed
# Row Group #266: 167,391 rows, 8.83 MB compressed
# Row Group #267: 167,391 rows, 7.43 MB compressed
# Row Group #268: 167,391 rows, 9.87 MB compressed
# Row Group #269: 167,391 rows, 13.26 MB compressed
# Row Group #270: 167,391 rows, 10.11 MB compressed
# Row Group #271: 167,391 rows, 13.12 MB compressed
# Row Group #272: 167,391 rows, 14.07 MB compressed
# Row Group #273: 167,391 rows, 7.89 MB compressed
# Row Group #274: 167,391 rows, 10.70 MB compressed
# Row Group #275: 167,391 rows, 10.78 MB compressed
# Row Group #276: 167,391 rows, 9.36 MB compressed
# Row Group #277: 167,391 rows, 9.72 MB compressed
# Row Group #278: 167,391 rows, 9.67 MB compressed
# Row Group #279: 143,478 rows, 8.81 MB compressed
# Row Group #280: 167,391 rows, 8.93 MB compressed
# Row Group #281: 167,391 rows, 8.73 MB compressed
# Row Group #282: 167,391 rows, 8.55 MB compressed
# Row Group #283: 167,391 rows, 10.72 MB compressed
# Row Group #284: 167,391 rows, 8.71 MB compressed
# Row Group #285: 167,391 rows, 8.08 MB compressed
# Row Group #286: 167,391 rows, 8.39 MB compressed
# Row Group #287: 167,391 rows, 9.48 MB compressed
# Row Group #288: 167,391 rows, 8.63 MB compressed
# Row Group #289: 167,391 rows, 8.76 MB compressed
# Row Group #290: 167,391 rows, 8.48 MB compressed
# Row Group #291: 167,391 rows, 8.60 MB compressed
# Row Group #292: 167,391 rows, 8.17 MB compressed
# Row Group #293: 167,391 rows, 8.34 MB compressed
# Row Group #294: 167,391 rows, 8.01 MB compressed
# Row Group #295: 167,391 rows, 7.94 MB compressed
# Row Group #296: 167,391 rows, 8.13 MB compressed
# Row Group #297: 167,391 rows, 7.92 MB compressed
# Row Group #298: 167,391 rows, 8.21 MB compressed
# Row Group #299: 167,391 rows, 8.63 MB compressed
# Row Group #300: 167,391 rows, 11.65 MB compressed
# Row Group #301: 167,391 rows, 8.41 MB compressed
# Row Group #302: 167,391 rows, 7.60 MB compressed
# Row Group #303: 167,391 rows, 7.92 MB compressed
# Row Group #304: 167,391 rows, 7.60 MB compressed
# Row Group #305: 167,391 rows, 11.20 MB compressed
# Row Group #306: 167,391 rows, 6.68 MB compressed
# Row Group #307: 167,391 rows, 7.28 MB compressed
# Row Group #308: 167,391 rows, 13.05 MB compressed
# Row Group #309: 167,391 rows, 11.10 MB compressed
# Row Group #310: 167,391 rows, 9.57 MB compressed
# Row Group #311: 167,391 rows, 10.59 MB compressed
# Row Group #312: 167,391 rows, 9.40 MB compressed
# Row Group #313: 167,391 rows, 9.83 MB compressed
# Row Group #314: 167,391 rows, 11.05 MB compressed
# Row Group #315: 167,391 rows, 8.03 MB compressed
# Row Group #316: 167,391 rows, 13.97 MB compressed
# Row Group #317: 167,391 rows, 11.99 MB compressed
# Row Group #318: 167,391 rows, 12.93 MB compressed
# Row Group #319: 167,391 rows, 13.98 MB compressed
# Row Group #320: 167,391 rows, 10.47 MB compressed
# Row Group #321: 167,391 rows, 13.57 MB compressed
# Row Group #322: 167,391 rows, 8.86 MB compressed
# Row Group #323: 167,391 rows, 13.75 MB compressed
# Row Group #324: 167,391 rows, 12.27 MB compressed
# Row Group #325: 167,391 rows, 11.17 MB compressed
# Row Group #326: 167,391 rows, 9.93 MB compressed
# Row Group #327: 167,391 rows, 10.22 MB compressed
# Row Group #328: 167,391 rows, 8.21 MB compressed
# Row Group #329: 167,391 rows, 11.85 MB compressed
# Row Group #330: 167,391 rows, 8.80 MB compressed
# Row Group #331: 167,391 rows, 9.70 MB compressed
# Row Group #332: 167,391 rows, 13.32 MB compressed
# Row Group #333: 167,391 rows, 13.35 MB compressed
# Row Group #334: 167,391 rows, 8.68 MB compressed
# Row Group #335: 167,391 rows, 11.04 MB compressed
# Row Group #336: 167,391 rows, 8.48 MB compressed
# Row Group #337: 167,391 rows, 8.33 MB compressed
# Row Group #338: 167,391 rows, 8.47 MB compressed
# Row Group #339: 167,391 rows, 8.37 MB compressed
# Row Group #340: 167,391 rows, 8.22 MB compressed
# Row Group #341: 167,391 rows, 8.10 MB compressed
# Row Group #342: 167,391 rows, 8.21 MB compressed
# Row Group #343: 167,391 rows, 8.97 MB compressed
# Row Group #344: 167,391 rows, 8.15 MB compressed
# Row Group #345: 167,391 rows, 9.22 MB compressed
# Row Group #346: 167,391 rows, 8.15 MB compressed
# Row Group #347: 167,391 rows, 8.34 MB compressed
# Row Group #348: 167,391 rows, 8.71 MB compressed
# Row Group #349: 167,391 rows, 9.22 MB compressed
# Row Group #350: 167,391 rows, 10.02 MB compressed
# Row Group #351: 167,391 rows, 9.90 MB compressed
# Row Group #352: 167,391 rows, 7.82 MB compressed
# Row Group #353: 167,391 rows, 8.47 MB compressed
# Row Group #354: 167,391 rows, 7.77 MB compressed
# Row Group #355: 167,391 rows, 9.02 MB compressed
# Row Group #356: 167,391 rows, 7.23 MB compressed
# Row Group #357: 167,391 rows, 7.16 MB compressed
# Row Group #358: 167,391 rows, 7.64 MB compressed
# Row Group #359: 167,391 rows, 9.66 MB compressed
# Row Group #360: 167,391 rows, 11.04 MB compressed
# Row Group #361: 167,391 rows, 10.66 MB compressed
# Row Group #362: 167,391 rows, 8.68 MB compressed
# Row Group #363: 167,391 rows, 13.50 MB compressed
# Row Group #364: 167,391 rows, 13.80 MB compressed
# Row Group #365: 167,391 rows, 11.56 MB compressed
# Row Group #366: 167,391 rows, 10.77 MB compressed
# Row Group #367: 167,391 rows, 10.59 MB compressed
# Row Group #368: 167,391 rows, 8.15 MB compressed
# Row Group #369: 167,391 rows, 9.22 MB compressed
# Row Group #370: 167,391 rows, 7.51 MB compressed
# Row Group #371: 167,391 rows, 11.08 MB compressed
# Row Group #372: 167,391 rows, 8.56 MB compressed
# Row Group #373: 167,391 rows, 8.48 MB compressed
# Row Group #374: 167,391 rows, 9.32 MB compressed
# Row Group #375: 167,391 rows, 12.62 MB compressed
# Row Group #376: 167,391 rows, 12.94 MB compressed
# Row Group #377: 167,391 rows, 12.69 MB compressed
# Row Group #378: 167,391 rows, 10.58 MB compressed
# Row Group #379: 167,391 rows, 12.29 MB compressed
# Row Group #380: 167,391 rows, 8.97 MB compressed
# Row Group #381: 167,391 rows, 9.07 MB compressed
# Row Group #382: 167,391 rows, 8.15 MB compressed
# Row Group #383: 167,391 rows, 8.70 MB compressed
# Row Group #384: 167,391 rows, 11.54 MB compressed
# Row Group #385: 167,391 rows, 9.97 MB compressed
# Row Group #386: 167,391 rows, 9.42 MB compressed
# Row Group #387: 167,391 rows, 9.70 MB compressed
# Row Group #388: 167,391 rows, 9.20 MB compressed
# Row Group #389: 167,391 rows, 8.10 MB compressed
# Row Group #390: 167,391 rows, 8.47 MB compressed
# Row Group #391: 167,391 rows, 8.73 MB compressed
# Row Group #392: 167,391 rows, 8.28 MB compressed
# Row Group #393: 167,391 rows, 8.26 MB compressed
# Row Group #394: 167,391 rows, 8.70 MB compressed
# Row Group #395: 167,391 rows, 8.40 MB compressed
# Row Group #396: 167,391 rows, 8.34 MB compressed
# Row Group #397: 167,391 rows, 8.97 MB compressed
# Row Group #398: 167,391 rows, 9.12 MB compressed
# Row Group #399: 167,391 rows, 8.35 MB compressed
# Row Group #400: 167,391 rows, 8.23 MB compressed
# Row Group #401: 167,391 rows, 8.04 MB compressed
# Row Group #402: 167,391 rows, 8.39 MB compressed
# Row Group #403: 167,391 rows, 7.77 MB compressed
# Row Group #404: 167,391 rows, 7.71 MB compressed
# Row Group #405: 167,391 rows, 8.53 MB compressed
# Row Group #406: 167,391 rows, 8.20 MB compressed
# Row Group #407: 167,391 rows, 8.08 MB compressed
# Row Group #408: 167,391 rows, 7.32 MB compressed
# Row Group #409: 167,391 rows, 11.04 MB compressed
# Row Group #410: 167,391 rows, 9.32 MB compressed
# Row Group #411: 167,391 rows, 7.22 MB compressed
# Row Group #412: 167,391 rows, 9.76 MB compressed
# Row Group #413: 167,391 rows, 9.96 MB compressed
# Row Group #414: 167,391 rows, 7.95 MB compressed
# Row Group #415: 167,391 rows, 10.10 MB compressed
# Row Group #416: 167,391 rows, 10.67 MB compressed
# Row Group #417: 167,391 rows, 14.39 MB compressed
# Row Group #418: 167,391 rows, 14.98 MB compressed
# Row Group #419: 167,391 rows, 14.27 MB compressed
# Row Group #420: 167,391 rows, 14.62 MB compressed
# Row Group #421: 167,391 rows, 15.94 MB compressed
# Row Group #422: 167,391 rows, 15.65 MB compressed
# Row Group #423: 167,391 rows, 17.11 MB compressed
# Row Group #424: 167,391 rows, 14.96 MB compressed
# Row Group #425: 167,391 rows, 13.33 MB compressed
# Row Group #426: 167,391 rows, 14.13 MB compressed
# Row Group #427: 167,391 rows, 16.66 MB compressed
# Row Group #428: 167,391 rows, 16.10 MB compressed
# Row Group #429: 167,391 rows, 14.35 MB compressed
# Row Group #430: 167,391 rows, 13.42 MB compressed
# Row Group #431: 167,391 rows, 13.48 MB compressed
# Row Group #432: 167,391 rows, 13.66 MB compressed
# Row Group #433: 167,391 rows, 14.34 MB compressed
# Row Group #434: 167,391 rows, 15.06 MB compressed
# Row Group #435: 167,391 rows, 13.49 MB compressed
# Row Group #436: 167,391 rows, 14.23 MB compressed
# Row Group #437: 167,391 rows, 13.60 MB compressed
# Row Group #438: 167,391 rows, 13.73 MB compressed
# Row Group #439: 167,391 rows, 14.47 MB compressed
# Row Group #440: 167,391 rows, 14.36 MB compressed
# Row Group #441: 167,391 rows, 14.14 MB compressed
# Row Group #442: 167,391 rows, 13.91 MB compressed
# Row Group #443: 167,391 rows, 13.98 MB compressed
# Row Group #444: 167,391 rows, 13.65 MB compressed
# Row Group #445: 167,391 rows, 13.95 MB compressed
# Row Group #446: 167,391 rows, 14.03 MB compressed
# Row Group #447: 167,391 rows, 13.61 MB compressed
# Row Group #448: 167,391 rows, 15.14 MB compressed
# Row Group #449: 167,391 rows, 13.66 MB compressed
# Row Group #450: 167,391 rows, 13.72 MB compressed
# Row Group #451: 167,391 rows, 13.66 MB compressed
# Row Group #452: 167,391 rows, 13.80 MB compressed
# Row Group #453: 167,391 rows, 14.48 MB compressed
# Row Group #454: 167,391 rows, 14.28 MB compressed
# Row Group #455: 167,391 rows, 13.54 MB compressed
# Row Group #456: 167,391 rows, 13.90 MB compressed
# Row Group #457: 167,391 rows, 14.40 MB compressed
# Row Group #458: 167,391 rows, 14.83 MB compressed
# Row Group #459: 167,391 rows, 16.43 MB compressed
# Row Group #460: 167,391 rows, 15.20 MB compressed
# Row Group #461: 167,391 rows, 13.11 MB compressed
# Row Group #462: 167,391 rows, 15.11 MB compressed
# Row Group #463: 167,391 rows, 14.73 MB compressed
# Row Group #464: 167,391 rows, 13.95 MB compressed
# Row Group #465: 167,391 rows, 13.20 MB compressed
# Row Group #466: 167,391 rows, 15.94 MB compressed
# Row Group #467: 167,391 rows, 16.03 MB compressed
# Row Group #468: 167,391 rows, 17.07 MB compressed
# Row Group #469: 167,391 rows, 14.57 MB compressed
# Row Group #470: 167,391 rows, 13.02 MB compressed
# Row Group #471: 167,391 rows, 15.79 MB compressed
# Row Group #472: 167,391 rows, 13.14 MB compressed
# Row Group #473: 167,391 rows, 12.59 MB compressed
# Row Group #474: 167,391 rows, 12.84 MB compressed
# Row Group #475: 167,391 rows, 13.03 MB compressed
# Row Group #476: 167,391 rows, 13.74 MB compressed
# Row Group #477: 167,391 rows, 14.86 MB compressed
# Row Group #478: 167,391 rows, 15.47 MB compressed
# Row Group #479: 167,391 rows, 13.69 MB compressed
# Row Group #480: 167,391 rows, 15.24 MB compressed
# Row Group #481: 167,391 rows, 14.16 MB compressed
# Row Group #482: 167,391 rows, 14.76 MB compressed
# Row Group #483: 167,391 rows, 14.26 MB compressed
# Row Group #484: 167,391 rows, 16.15 MB compressed
# Row Group #485: 167,391 rows, 16.34 MB compressed
# Row Group #486: 167,391 rows, 14.26 MB compressed
# Row Group #487: 167,391 rows, 14.84 MB compressed
# Row Group #488: 167,391 rows, 15.00 MB compressed
# Row Group #489: 167,391 rows, 14.24 MB compressed
# Row Group #490: 167,391 rows, 13.80 MB compressed
# Row Group #491: 167,391 rows, 14.72 MB compressed
# Row Group #492: 167,391 rows, 14.38 MB compressed
# Row Group #493: 167,391 rows, 14.28 MB compressed
# Row Group #494: 167,391 rows, 14.15 MB compressed
# Row Group #495: 167,391 rows, 13.94 MB compressed
# Row Group #496: 167,391 rows, 13.99 MB compressed
# Row Group #497: 167,391 rows, 13.51 MB compressed
# Row Group #498: 167,391 rows, 13.83 MB compressed
# Row Group #499: 167,391 rows, 14.54 MB compressed
# Row Group #500: 167,391 rows, 15.12 MB compressed
# Row Group #501: 167,391 rows, 14.15 MB compressed
# Row Group #502: 167,391 rows, 13.76 MB compressed
# Row Group #503: 167,391 rows, 14.05 MB compressed
# Row Group #504: 167,391 rows, 13.52 MB compressed
# Row Group #505: 167,391 rows, 15.02 MB compressed
# Row Group #506: 167,391 rows, 14.86 MB compressed
# Row Group #507: 167,391 rows, 15.03 MB compressed
# Row Group #508: 167,391 rows, 13.60 MB compressed
# Row Group #509: 167,391 rows, 13.25 MB compressed
# Row Group #510: 167,391 rows, 13.95 MB compressed
# Row Group #511: 167,391 rows, 13.94 MB compressed
# Row Group #512: 167,391 rows, 13.07 MB compressed
# Row Group #513: 167,391 rows, 16.28 MB compressed
# Row Group #514: 167,391 rows, 15.73 MB compressed
# Row Group #515: 167,391 rows, 12.78 MB compressed
# Row Group #516: 167,391 rows, 12.94 MB compressed
# Row Group #517: 167,391 rows, 15.89 MB compressed
# Row Group #518: 167,391 rows, 12.92 MB compressed
# Row Group #519: 167,391 rows, 16.17 MB compressed
# Row Group #520: 167,391 rows, 14.18 MB compressed
# Row Group #521: 167,391 rows, 17.21 MB compressed
# Row Group #522: 167,391 rows, 17.40 MB compressed
# Row Group #523: 167,391 rows, 17.37 MB compressed
# Row Group #524: 167,391 rows, 14.63 MB compressed
# Row Group #525: 167,391 rows, 13.56 MB compressed
# Row Group #526: 143,478 rows, 12.17 MB compressed
# Row Group #527: 167,391 rows, 15.27 MB compressed
# Row Group #528: 167,391 rows, 13.60 MB compressed
# Row Group #529: 167,391 rows, 17.24 MB compressed
# Row Group #530: 167,391 rows, 16.45 MB compressed
# Row Group #531: 167,391 rows, 17.10 MB compressed
# Row Group #532: 167,391 rows, 16.39 MB compressed
# Row Group #533: 167,391 rows, 16.43 MB compressed
# Row Group #534: 167,391 rows, 16.40 MB compressed
# Row Group #535: 167,391 rows, 14.78 MB compressed
# Row Group #536: 167,391 rows, 14.05 MB compressed
# Row Group #537: 167,391 rows, 13.84 MB compressed
# Row Group #538: 167,391 rows, 14.63 MB compressed
# Row Group #539: 167,391 rows, 16.92 MB compressed
# Row Group #540: 167,391 rows, 14.54 MB compressed
# Row Group #541: 167,391 rows, 14.31 MB compressed
# Row Group #542: 167,391 rows, 14.84 MB compressed
# Row Group #543: 167,391 rows, 14.59 MB compressed
# Row Group #544: 167,391 rows, 16.33 MB compressed
# Row Group #545: 167,391 rows, 14.25 MB compressed
# Row Group #546: 167,391 rows, 14.60 MB compressed
# Row Group #547: 167,391 rows, 14.18 MB compressed
# Row Group #548: 167,391 rows, 13.71 MB compressed
# Row Group #549: 167,391 rows, 13.67 MB compressed
# Row Group #550: 167,391 rows, 13.72 MB compressed
# Row Group #551: 167,391 rows, 13.87 MB compressed
# Row Group #552: 167,391 rows, 13.64 MB compressed
# Row Group #553: 167,391 rows, 16.21 MB compressed
# Row Group #554: 167,391 rows, 14.33 MB compressed
# Row Group #555: 167,391 rows, 14.60 MB compressed
# Row Group #556: 167,391 rows, 15.65 MB compressed
# Row Group #557: 167,391 rows, 13.70 MB compressed
# Row Group #558: 167,391 rows, 13.95 MB compressed
# Row Group #559: 167,391 rows, 13.67 MB compressed
# Row Group #560: 167,391 rows, 15.53 MB compressed
# Row Group #561: 167,391 rows, 13.88 MB compressed
# Row Group #562: 167,391 rows, 14.53 MB compressed
# Row Group #563: 167,391 rows, 13.75 MB compressed
# Row Group #564: 167,391 rows, 14.49 MB compressed
# Row Group #565: 167,391 rows, 13.33 MB compressed
# Row Group #566: 167,391 rows, 14.39 MB compressed
# Row Group #567: 167,391 rows, 16.39 MB compressed
# Row Group #568: 167,391 rows, 14.10 MB compressed
# Row Group #569: 167,391 rows, 14.33 MB compressed
# Row Group #570: 167,391 rows, 13.51 MB compressed
# Row Group #571: 167,391 rows, 16.12 MB compressed
# Row Group #572: 167,391 rows, 14.64 MB compressed
# Row Group #573: 167,391 rows, 15.44 MB compressed
# Row Group #574: 167,391 rows, 15.87 MB compressed
# Row Group #575: 167,391 rows, 16.02 MB compressed
# Row Group #576: 167,391 rows, 16.33 MB compressed
# Row Group #577: 167,391 rows, 15.97 MB compressed
# Row Group #578: 167,391 rows, 17.00 MB compressed
# Row Group #579: 167,391 rows, 16.34 MB compressed
# Row Group #580: 167,391 rows, 15.87 MB compressed
# Row Group #581: 167,391 rows, 15.69 MB compressed
# Row Group #582: 167,391 rows, 16.50 MB compressed
# Row Group #583: 167,391 rows, 15.90 MB compressed
# Row Group #584: 167,391 rows, 15.15 MB compressed
# Row Group #585: 167,391 rows, 15.74 MB compressed
# Row Group #586: 167,391 rows, 16.78 MB compressed
# Row Group #587: 167,391 rows, 15.90 MB compressed
# Row Group #588: 167,391 rows, 15.69 MB compressed
# Row Group #589: 167,391 rows, 13.89 MB compressed
# Row Group #590: 167,391 rows, 15.18 MB compressed
# Row Group #591: 167,391 rows, 13.97 MB compressed
# Row Group #592: 167,391 rows, 15.33 MB compressed
# Row Group #593: 167,391 rows, 13.92 MB compressed
# Row Group #594: 167,391 rows, 13.66 MB compressed
# Row Group #595: 167,391 rows, 13.74 MB compressed
# Row Group #596: 167,391 rows, 14.09 MB compressed
# Row Group #597: 167,391 rows, 13.80 MB compressed
# Row Group #598: 167,391 rows, 13.73 MB compressed
# Row Group #599: 167,391 rows, 13.82 MB compressed
# Row Group #600: 167,391 rows, 14.23 MB compressed
# Row Group #601: 167,391 rows, 13.65 MB compressed
# Row Group #602: 167,391 rows, 14.13 MB compressed
# Row Group #603: 167,391 rows, 14.05 MB compressed
# Row Group #604: 167,391 rows, 14.23 MB compressed
# Row Group #605: 167,391 rows, 13.73 MB compressed
# Row Group #606: 167,391 rows, 13.87 MB compressed
# Row Group #607: 167,391 rows, 14.59 MB compressed
# Row Group #608: 167,391 rows, 13.50 MB compressed
# Row Group #609: 167,391 rows, 13.63 MB compressed
# Row Group #610: 167,391 rows, 14.07 MB compressed
# Row Group #611: 167,391 rows, 14.59 MB compressed
# Row Group #612: 71,739 rows, 7.11 MB compressed
# Row Group #613: 167,391 rows, 13.51 MB compressed
# Row Group #614: 167,391 rows, 13.36 MB compressed
# Row Group #615: 167,391 rows, 14.10 MB compressed
# Row Group #616: 167,391 rows, 14.24 MB compressed
# Row Group #617: 167,391 rows, 14.03 MB compressed
#
# === Column Details ===
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 57
#      54     return cols_df
#      56 # Call the function with our parquet file
# ---> 57 metadata_stats = analyze_parquet_metadata(path_file)
#
# Cell In[16], line 31, in analyze_parquet_metadata(file_path)
#      27     for j in range(row_group.num_columns):
#      28         col = row_group.column(j)
#      29         all_cols.append({
#      30             'name': col.path_in_schema,
# ---> 31             'type': schema.field_by_name(col.path_in_schema).type,
#      32             'compression': col.compression,
#      33             'size_mb': col.total_compressed_size / (1024*1024),
#      34             'encodings': col.encodings
#      35         })
#      37 # Convert to dataframe for easy display
#      38 cols_df = pd.DataFrame(all_cols)
#
# AttributeError: 'pyarrow._parquet.ParquetSchema' object has no attribute 'field_by_name'

# %%
# Calculate and display basic statistics for numerical columns
def display_basic_statistics(data_sample):
    """Calculate and display basic statistics for the dataset"""
    # Read more data for better statistical analysis (still using efficient loading)
    parquet_file = pq.ParquetFile(path_file)
    # Try to get a larger sample for statistics (not too large to avoid memory issues)
    stats_sample_size = min(10000, parquet_file.metadata.num_rows)
    stats_sample = parquet_file.read_row_group(0).to_pandas().head(stats_sample_size)
    
    # Get numerical columns only
    numeric_cols = stats_sample.select_dtypes(include=['number']).columns.tolist()
    
    if not numeric_cols:
        print("No numerical columns found in the dataset.")
        return
    
    # Calculate statistics
    print(f"=== Basic Statistics (based on {stats_sample_size:,} rows) ===")
    stats_df = stats_sample[numeric_cols].describe().T
    
    # Add more metrics
    stats_df['missing'] = stats_sample[numeric_cols].isna().sum()
    stats_df['missing_pct'] = (stats_sample[numeric_cols].isna().sum() / len(stats_sample)) * 100
    
    # Round for better display
    stats_df = stats_df.round(2)
    
    # Display as styled table
    from IPython.display import display, HTML
    style = """
    <style>
        .stats-desc-table {width: 100%; border-collapse: collapse;}
        .stats-desc-table th {background-color: #e6ffe6; color: black; text-align: left; padding: 8px; border: 1px solid #ddd;}
        .stats-desc-table td {padding: 8px; border: 1px solid #ddd;}
        .stats-desc-table tr:nth-child(even) {background-color: #f9f9f9;}
        .stats-desc-table tr:hover {background-color: #f2f2f2;}
    </style>
    """
    display(HTML(style + stats_df.to_html(classes='stats-desc-table')))
    
    return stats_df

# Call the function with our data sample
stats_df = display_basic_statistics(data)

# %% [markdown]
# ## Data Visualizations
#
# Below are some visualizations to help understand the distribution of key variables in the weather features dataset.

# %%
# Visualize distributions of key variables
import matplotlib.pyplot as plt
import seaborn as sns

# Try to get a sample size that works for visualization but isn't too large
def plot_key_distributions(file_path, sample_size=5000):
    """Create distribution plots for key numerical variables"""
    # Get a reasonable sample for visualization
    parquet_file = pq.ParquetFile(file_path)
    sample_size = min(sample_size, parquet_file.metadata.num_rows)
    vis_sample = parquet_file.read_row_group(0).to_pandas().head(sample_size)
    
    # Get numerical columns only
    numeric_cols = vis_sample.select_dtypes(include=['number']).columns.tolist()
    
    # Select a subset of interesting columns (up to 6) to visualize
    if len(numeric_cols) > 6:
        # Prioritize columns with names related to temperature, precipitation, wind, etc.
        priority_keywords = ['temp', 'prcp', 'wind', 'humid', 'fire', 'pressure']
        priority_cols = []
        for keyword in priority_keywords:
            priority_cols.extend([c for c in numeric_cols if keyword.lower() in c.lower()])
        
        # If we found priority columns, use them, otherwise use first 6
        cols_to_plot = priority_cols[:6] if priority_cols else numeric_cols[:6]
    else:
        cols_to_plot = numeric_cols
    
    # Create distribution plots
    fig, axes = plt.subplots(len(cols_to_plot), 1, figsize=(10, 3*len(cols_to_plot)))
    if len(cols_to_plot) == 1:
        axes = [axes]  # Make sure axes is always iterable
    
    for i, col in enumerate(cols_to_plot):
        sns.histplot(vis_sample[col].dropna(), ax=axes[i], kde=True)
        axes[i].set_title(f'Distribution of {col}')
        axes[i].grid(True, linestyle='--', alpha=0.7)
    
    plt.tight_layout()
    plt.show()

# Call the visualization function
plot_key_distributions(path_file)
